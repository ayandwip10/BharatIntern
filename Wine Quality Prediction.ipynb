# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the Dataset
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# to display statistical info about data
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# to display basic info about datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# to display no. of rows and columns of the dataset
df.shape
# Out:
# (1599, 12)

# %%
# histogrms
df.hist(bins=25, figsize=(10, 10))
plt.show()

# %%
# bar plot
plt.figure(figsize=[7, 3])
plt.bar(df['quality'], df['alcohol'], color='grey')
plt.xlabel('quality')
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
# box plot
plt.figure(figsize=(15, 8))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# Coorelation Matrix
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# Separating features and target
X = df.drop(['quality'], axis=1)
y = df['quality']

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
# preprocessing the data
scaler = StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
# Spilitting the Data into Train and Test dataset
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.2)

# %%
X_train
# Out:
# array([[-1.10289006,  0.23563472, -0.67256581, ...,  0.05758008,
#         -1.05131114, -1.1479806 ],
#        [-0.87307788,  0.90601191, -1.39147228, ...,  0.96467901,
#          0.36500271, -0.20930812],
#        [-0.18364134,  1.68811863, -0.0050098 , ..., -0.13679827,
#         -1.05131114, -0.58477711],
#        ...,
#        [-0.01128221, -1.49617302,  0.76524713, ..., -0.65514052,
#          0.83710732, -0.96024611],
#        [-0.18364134, -1.21684919,  0.91929852, ..., -1.0438972 ,
#          0.8961204 ,  1.94963861],
#        [-0.93053092,  0.06804042, -0.72391627, ...,  1.93657073,
#         -0.10710191, -0.58477711]])

# %%
y_train
# Out:
# 1394    5
# 624     5
# 1363    4
# 1374    3
# 1514    6
#        ..
# 589     7
# 1166    5
# 380     6
# 1098    7
# 822     5
# Name: quality, Length: 1279, dtype: int64

# %%
# Linear Regression
linreg = LinearRegression()
# model training
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# make prediction
y_pred = linreg.predict(X_test)

# %%
data = pd.DataFrame({"Actual":y_test, "Predicted":y_pred})

# %%
data.head()
# Out:
#       Actual  Predicted
# 1206       7   6.114763
# 1156       7   6.416451
# 241        6   6.028709
# 1372       5   4.883674
# 449        6   5.873828

# %%
plt.plot(X_test, y_test, 'o')
